# %%
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd
import mne
import warnings
warnings.filterwarnings('ignore')

# %%
link = "Epileptic Seizure Recognition.csv"
df = pd.read_csv(link)
df.head()
# Out:
#       Unnamed   X1   X2   X3   X4   X5   X6   X7   X8   X9  ...  X170  X171  \
# 0  X21.V1.791  135  190  229  223  192  125   55   -9  -33  ...   -17   -15
# 1  X15.V1.924  386  382  356  331  320  315  307  272  244  ...   164   150
# 2     X8.V1.1  -32  -39  -47  -37  -32  -36  -57  -73  -85  ...    57    64
# 3   X16.V1.60 -105 -101  -96  -92  -89  -95 -102 -100  -87  ...   -82   -81
# 4   X20.V1.54   -9  -65  -98 -102  -78  -48  -16    0  -21  ...     4     2
#
#    X172  X173  X174  X175  X176  X177  X178  y
# 0   -31   -77  -103  -127  -116   -83   -51  4
# 1   146   152   157   156   154   143   129  1
# 2    48    19   -12   -30   -35   -35   -36  5
# 3   -80   -77   -85   -77   -72   -69   -65  5
# 4   -12   -32   -41   -65   -83   -89   -73  5
#
# [5 rows x 180 columns]

# %%
df=df.drop(['Unnamed'], axis=1)

# %%
df.shape
# Out:
# (11500, 179)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
cols = df.columns
tgt = df.y
print(tgt.value_counts())
sn.countplot(x=df["y"],label="Count")
# Out:
# 4    2300
# 1    2300
# 5    2300
# 2    2300
# 3    2300
# Name: y, dtype: int64
# <AxesSubplot: xlabel='y', ylabel='count'>

# %%
sn.heatmap(df.corr())
# Out:
# <AxesSubplot: >

# %%
plt.plot(  [ i for i  in range(0,178) ]   ,  df[df['y']==1].iloc[0][:-1] , color='red')

# %%
plt.plot(  [ i for i  in range(0,178) ]   ,  df[df['y']==2].iloc[0][:-1] , color='red')

# %%
plt.plot(  [ i for i  in range(0,178) ]   ,  df[df['y']==3].iloc[0][:-1] , color='red')

# %%
plt.plot(  [ i for i  in range(0,178) ]   ,  df[df['y']==4].iloc[0][:-1] , color='green')

# %%
plt.plot(  [ i for i  in range(0,178) ]   ,  df[df['y']==5].iloc[0][:-1] , color='green')
